# %%
import os
import sys
import json
import time
import requests

from dotenv import load_dotenv

def setup_env():
    
    env_path = os.path.join(os.getcwd(), '../.env')

    if os.path.exists(env_path):
        load_dotenv(dotenv_path=env_path)
        
        print(f"Loaded environment variables from: \033[94m{env_path}\033[0m")
    else:
            print("\033[91mError: .env file not found. Please create one with your OPENAI_API_KEY.\033[0m")
            sys.exit(1)

setup_env()
# Out:
# Loaded environment variables from: /home/ras/0.ai_agent_ws/src/learn_llm/learn_rag_and_agent/../.env

# %%
email_raw_content = """From: 김철수 (chulsoo.kim@bikecorporation.me)
To: 이은채 (eunchae@teddyinternational.me)
Subject: "ZENESIS" 자전거 유통 협력 및 미팅 일정 제안

안녕하세요, 이은채 대리님,

저는 바이크코퍼레이션의 김철수 상무입니다. 최근 보도자료를 통해 귀사의 신규 자전거 "ZENESIS"에 대해 알게 되었습니다. 바이크코퍼레이션은 자전거 제조 및 유통 분야에서 혁신과 품질을 선도하는 기업으로, 이 분야에서의 장기적인 경험과 전문성을 가지고 있습니다.

ZENESIS 모델에 대한 상세한 브로슈어를 요청드립니다. 특히 기술 사양, 배터리 성능, 그리고 디자인 측면에 대한 정보가 필요합니다. 이를 통해 저희가 제안할 유통 전략과 마케팅 계획을 보다 구체화할 수 있을 것입니다.

또한, 협력 가능성을 더 깊이 논의하기 위해 다음 주 화요일(1월 15일) 오전 10시에 미팅을 제안합니다. 귀사 사무실에서 만나 이야기를 나눌 수 있을까요?

감사합니다.

김철수
상무이사
바이크코퍼레이션
"""

# %%
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI

prompt = PromptTemplate.from_template(
    """ 다음의 이메일 내용 중 중요한 내용을 추출해 주세요 \
        - 이메일 내용: {email_raw_content}""",
)

llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")

chain = prompt | llm

response = chain.invoke({"email_raw_content": email_raw_content})

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 10
#       3 from langchain.chat_models import ChatOpenAI
#       5 prompt = PromptTemplate.from_template(
#       6     """ 다음의 이메일 내용 중 중요한 내용을 추출해 주세요 \
#       7         - 이메일 내용: {email_raw_content}""",
#       8 )
# ---> 10 llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")
#      12 chain = prompt | llm
#      14 response = chain.invoke({"email_raw_content": email_raw_content})
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:214, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     212     warned = True
#     213     emit_warning()
# --> 214 return wrapped(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/load/serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/pydantic/_internal/_decorators_v1.py:148, in make_v1_generic_root_validator.<locals>._wrapper1(values, _)
#     147 def _wrapper1(values: RootValidatorValues, _: core_schema.ValidationInfo) -> RootValidatorValues:
# --> 148     return validator(values)
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/utils/pydantic.py:217, in pre_init.<locals>.wrapper(cls, values)
#     213 if (
#     214     name not in values or values[name] is None
#     215 ) and not field_info.is_required():
#     216     if field_info.default_factory is not None:
# --> 217         values[name] = field_info.default_factory()  # type: ignore
#     218     else:
#     219         values[name] = field_info.default
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/language_models/base.py:92, in _get_verbosity()
#      89 def _get_verbosity() -> bool:
#      90     from langchain_core.globals import get_verbose
# ---> 92     return get_verbose()
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/globals.py:81, in get_verbose()
#      64         warnings.filterwarnings(
#      65             "ignore",
#      66             message=(
#      67                 ".*Importing verbose from langchain root module is no longer supported"
#      68             ),
#      69         )
#      70         # N.B.: This is a workaround for an unfortunate quirk of Python's
#      71         #       module-level `__getattr__()` implementation:
#      72         # https://github.com/langchain-ai/langchain/pull/11311#issuecomment-1743780004
#    (...)
#      79         # to using `set_verbose()` yet. Those users are getting deprecation warnings
#      80         # directing them to use `set_verbose()` when they import `langchain.verbose`.
# ---> 81         old_verbose = langchain.verbose
#      82 except ImportError:
#      83     old_verbose = False
#
# AttributeError: module 'langchain' has no attribute 'verbose'

# %%
class EmailSummary(BaseModel):
    person: str = Field(description="메일을 보낸 사람")
    email: str = Field(description="메일을 보낸 사람의 이메일 주소")
    subject: str = Field(description="메일 제목")
    summary: str = Field(description="메일 본문을 요약한 텍스트")
    date: str = Field(description="메일 본문에 언급된 미팅 날짜와 시간")


# PydanticOutputParser 생성
parser = PydanticOutputParser(pydantic_object=EmailSummary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 class EmailSummary(BaseModel):
#       2     person: str = Field(description="메일을 보낸 사람")
#       3     email: str = Field(description="메일을 보낸 사람의 이메일 주소")
#
# NameError: name 'BaseModel' is not defined

# %%
# instruction 을 출력합니다.
print(parser.get_format_instructions())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # instruction 을 출력합니다.
# ----> 2 print(parser.get_format_instructions())
#
# NameError: name 'parser' is not defined

# %%
prompt = PromptTemplate.from_template(
    """
You are a helpful assistant. Please answer the following questions in KOREAN.

QUESTION:
{question}

EMAIL CONVERSATION:
{email_conversation}

FORMAT:
{format}
"""
)

# format 에 PydanticOutputParser의 부분 포맷팅(partial) 추가
prompt = prompt.partial(format=parser.get_format_instructions())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 prompt = PromptTemplate.from_template(
#       2     """
#       3 You are a helpful assistant. Please answer the following questions in KOREAN.
#       4
#       5 QUESTION:
#       6 {question}
#       7
#       8 EMAIL CONVERSATION:
#       9 {email_conversation}
#      10
#      11 FORMAT:
#      12 {format}
#      13 """
#      14 )
#      16 # format 에 PydanticOutputParser의 부분 포맷팅(partial) 추가
#      17 prompt = prompt.partial(format=parser.get_format_instructions())
#
# NameError: name 'PromptTemplate' is not defined

# %%
# chain 을 생성합니다.
chain = prompt | llm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # chain 을 생성합니다.
# ----> 2 chain = prompt | llm
#
# NameError: name 'prompt' is not defined

# %%
# chain 을 실행하고 결과를 출력합니다.
response = chain.invoke(
    {
        "email_raw_content": email_raw_content,
        "question": "이메일 내용중 주요 내용을 추출해 주세요.",
    }
)

# 결과는 JSON 형태로 출력됩니다.
print(response.content)
